# %% [markdown]
# # Timeseries classification from scratch
#
# **Author:** [hfawaz](https://github.com/hfawaz/)<br>
# **Date created:** 2020/07/21<br>
# **Last modified:** 2022/03/27 by B. Poczos<br>
# **Description:** Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive. <br>
# **Source:** https://keras.io/examples/timeseries/timeseries_classification_from_scratch/

# %% [markdown]
# ## Introduction
#
# This example shows how to do timeseries classification from scratch, starting from raw
# CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
# [UCR Time Series Classification Archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).

# %% [markdown]
# ## Setup

# %%
# !nvidia-smi
# Out:
# Sun Mar 27 17:10:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA.
# The data comes from the UCR archive.
# The dataset contains 3601 training instances and another 1320 testing instances.
# **Each timeseries corresponds to a measurement of engine noise captured by a motor sensor**.
# For this task, the **goal** is to automatically **detect the presence of a specific issue with
# the engine**. The problem is a balanced binary classification task. The full description of
# this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
#
# ### Read the TSV data
#
# We will use the `FordA_TRAIN` file for training and the
# `FordA_TEST` file for testing. The simplicity of this dataset
# allows us to demonstrate effectively how to use ConvNets for timeseries classification.
# In this file, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %% [markdown]
# 3601 training instances and another 1320 testing instances. Each time series has length 500

# %%
print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (3601, 500)
# (3601,)
# (1320, 500)
# (1320,)

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    print(f'class {c}: {c_x_train.shape}')
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()
# Out:
# class -1: (1846, 500)
# class 1: (1755, 500)

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are
# usually in various ranges. This is not ideal for a neural network;
# in general we should seek to make the input values normalized.
# For this specific dataset, the data is already z-normalized: each timeseries sample
# has a mean equal to zero and a standard deviation equal to one. This type of
# normalization is very common for timeseries classification problems, see
# [Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel
# per timeseries example.
# We will therefore transform the timeseries into a multivariate one with one channel
# using a simple reshaping via numpy.
# This will allow us to construct a model that is easily applicable to multivariate time
# series.

# %%
print(x_train.shape)
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
print(x_train.shape)

print(x_test.shape)
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
print(x_test.shape)
# Out:
# (3601, 500)
# (3601, 500, 1)
# (1320, 500)
# (1320, 500, 1)

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))
print(num_classes)
# Out:
# 2

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in
# [this paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided
# [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
# via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500, 1)]          0
#
#  conv1d (Conv1D)             (None, 500, 64)           256
#
#  batch_normalization (BatchN  (None, 500, 64)          256
#  ormalization)
#
#  re_lu (ReLU)                (None, 500, 64)           0
#
#  conv1d_1 (Conv1D)           (None, 500, 64)           12352
#
#  batch_normalization_1 (Batc  (None, 500, 64)          256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 500, 64)           0
#
#  conv1d_2 (Conv1D)           (None, 500, 64)           12352
#
#  batch_normalization_2 (Batc  (None, 500, 64)          256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 500, 64)           0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 25,858
# Trainable params: 25,474
# Non-trainable params: 384
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Train the model

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)

# %% [markdown]
# **Training**. </br>
# It will take a few minutes.

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 90/90 [==============================] - 12s 9ms/step - loss: 0.5536 - sparse_categorical_accuracy: 0.6931 - val_loss: 0.7484 - val_sparse_categorical_accuracy: 0.5215 - lr: 0.0010
# Epoch 2/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.4536 - sparse_categorical_accuracy: 0.7764 - val_loss: 0.8198 - val_sparse_categorical_accuracy: 0.5215 - lr: 0.0010
# Epoch 3/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.4425 - sparse_categorical_accuracy: 0.7778 - val_loss: 0.9622 - val_sparse_categorical_accuracy: 0.5215 - lr: 0.0010
# Epoch 4/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.4273 - sparse_categorical_accuracy: 0.7955 - val_loss: 0.6830 - val_sparse_categorical_accuracy: 0.5368 - lr: 0.0010
# Epoch 5/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.4121 - sparse_categorical_accuracy: 0.8010 - val_loss: 0.5660 - val_sparse_categorical_accuracy: 0.7143 - lr: 0.0010
# Epoch 6/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.4003 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.6858 - val_sparse_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 7/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3921 - sparse_categorical_accuracy: 0.8076 - val_loss: 0.5220 - val_sparse_categorical_accuracy: 0.7184 - lr: 0.0010
# Epoch 8/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.4006 - sparse_categorical_accuracy: 0.7951 - val_loss: 0.6218 - val_sparse_categorical_accuracy: 0.7115 - lr: 0.0010
# Epoch 9/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3844 - sparse_categorical_accuracy: 0.8184 - val_loss: 0.6154 - val_sparse_categorical_accuracy: 0.7115 - lr: 0.0010
# Epoch 10/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3966 - sparse_categorical_accuracy: 0.8052 - val_loss: 0.4260 - val_sparse_categorical_accuracy: 0.7767 - lr: 0.0010
# Epoch 11/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3679 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.3761 - val_sparse_categorical_accuracy: 0.8017 - lr: 0.0010
# Epoch 12/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3699 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.8110 - val_sparse_categorical_accuracy: 0.6671 - lr: 0.0010
# Epoch 13/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3545 - sparse_categorical_accuracy: 0.8361 - val_loss: 0.7332 - val_sparse_categorical_accuracy: 0.5936 - lr: 0.0010
# Epoch 14/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3476 - sparse_categorical_accuracy: 0.8441 - val_loss: 0.4077 - val_sparse_categorical_accuracy: 0.7476 - lr: 0.0010
# Epoch 15/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3376 - sparse_categorical_accuracy: 0.8462 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8003 - lr: 0.0010
# Epoch 16/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3381 - sparse_categorical_accuracy: 0.8542 - val_loss: 0.7117 - val_sparse_categorical_accuracy: 0.6269 - lr: 0.0010
# Epoch 17/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3213 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.4760 - val_sparse_categorical_accuracy: 0.7545 - lr: 0.0010
# Epoch 18/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3241 - sparse_categorical_accuracy: 0.8479 - val_loss: 0.3900 - val_sparse_categorical_accuracy: 0.7878 - lr: 0.0010
# Epoch 19/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.8698 - val_loss: 0.8082 - val_sparse_categorical_accuracy: 0.7323 - lr: 0.0010
# Epoch 20/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3144 - sparse_categorical_accuracy: 0.8642 - val_loss: 2.0121 - val_sparse_categorical_accuracy: 0.6352 - lr: 0.0010
# Epoch 21/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2933 - sparse_categorical_accuracy: 0.8757 - val_loss: 0.7576 - val_sparse_categorical_accuracy: 0.6755 - lr: 0.0010
# Epoch 22/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2986 - sparse_categorical_accuracy: 0.8733 - val_loss: 0.7324 - val_sparse_categorical_accuracy: 0.7323 - lr: 0.0010
# Epoch 23/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.3002 - sparse_categorical_accuracy: 0.8764 - val_loss: 0.2956 - val_sparse_categorical_accuracy: 0.8641 - lr: 0.0010
# Epoch 24/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2888 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3155 - val_sparse_categorical_accuracy: 0.8474 - lr: 0.0010
# Epoch 25/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2796 - sparse_categorical_accuracy: 0.8837 - val_loss: 1.2932 - val_sparse_categorical_accuracy: 0.5673 - lr: 0.0010
# Epoch 26/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.4202 - val_sparse_categorical_accuracy: 0.8086 - lr: 0.0010
# Epoch 27/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2946 - sparse_categorical_accuracy: 0.8708 - val_loss: 0.7568 - val_sparse_categorical_accuracy: 0.6158 - lr: 0.0010
# Epoch 28/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2686 - sparse_categorical_accuracy: 0.8899 - val_loss: 0.9164 - val_sparse_categorical_accuracy: 0.5756 - lr: 0.0010
# Epoch 29/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2637 - sparse_categorical_accuracy: 0.8941 - val_loss: 2.5995 - val_sparse_categorical_accuracy: 0.4785 - lr: 0.0010
# Epoch 30/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2654 - sparse_categorical_accuracy: 0.8965 - val_loss: 0.9040 - val_sparse_categorical_accuracy: 0.6949 - lr: 0.0010
# Epoch 31/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2586 - sparse_categorical_accuracy: 0.8938 - val_loss: 1.0919 - val_sparse_categorical_accuracy: 0.7337 - lr: 0.0010
# Epoch 32/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2455 - sparse_categorical_accuracy: 0.9014 - val_loss: 3.3266 - val_sparse_categorical_accuracy: 0.4785 - lr: 0.0010
# Epoch 33/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.8896 - val_loss: 1.2354 - val_sparse_categorical_accuracy: 0.5728 - lr: 0.0010
# Epoch 34/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2534 - sparse_categorical_accuracy: 0.9028 - val_loss: 1.2102 - val_sparse_categorical_accuracy: 0.7032 - lr: 0.0010
# Epoch 35/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2511 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.3983 - val_sparse_categorical_accuracy: 0.8044 - lr: 0.0010
# Epoch 36/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2499 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.3095 - val_sparse_categorical_accuracy: 0.8682 - lr: 0.0010
# Epoch 37/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2487 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.3927 - val_sparse_categorical_accuracy: 0.8100 - lr: 0.0010
# Epoch 38/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2556 - sparse_categorical_accuracy: 0.8941 - val_loss: 1.3140 - val_sparse_categorical_accuracy: 0.6227 - lr: 0.0010
# Epoch 39/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2481 - sparse_categorical_accuracy: 0.8990 - val_loss: 0.3565 - val_sparse_categorical_accuracy: 0.8280 - lr: 0.0010
# Epoch 40/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2287 - sparse_categorical_accuracy: 0.9108 - val_loss: 1.7402 - val_sparse_categorical_accuracy: 0.7309 - lr: 0.0010
# Epoch 41/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.8955 - val_loss: 2.2199 - val_sparse_categorical_accuracy: 0.5534 - lr: 0.0010
# Epoch 42/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9052 - val_loss: 1.2245 - val_sparse_categorical_accuracy: 0.7254 - lr: 0.0010
# Epoch 43/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2253 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.4994 - val_sparse_categorical_accuracy: 0.7254 - lr: 0.0010
# Epoch 44/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2146 - sparse_categorical_accuracy: 0.9104 - val_loss: 1.9060 - val_sparse_categorical_accuracy: 0.5811 - lr: 5.0000e-04
# Epoch 45/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.2152 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.5799 - val_sparse_categorical_accuracy: 0.7184 - lr: 5.0000e-04
# Epoch 46/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2033 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.2260 - val_sparse_categorical_accuracy: 0.9237 - lr: 5.0000e-04
# Epoch 47/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1997 - sparse_categorical_accuracy: 0.9181 - val_loss: 0.8790 - val_sparse_categorical_accuracy: 0.6907 - lr: 5.0000e-04
# Epoch 48/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1964 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.9691 - val_sparse_categorical_accuracy: 0.7406 - lr: 5.0000e-04
# Epoch 49/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.2172 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.8085 - val_sparse_categorical_accuracy: 0.7462 - lr: 5.0000e-04
# Epoch 50/500
# 90/90 [==============================] - 1s 8ms/step - loss: 0.2001 - sparse_categorical_accuracy: 0.9247 - val_loss: 0.7431 - val_sparse_categorical_accuracy: 0.7365 - lr: 5.0000e-04
# Epoch 51/500
# 90/90 [==============================] - 1s 8ms/step - loss: 0.1949 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.5756 - val_sparse_categorical_accuracy: 0.7406 - lr: 5.0000e-04
# Epoch 52/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1954 - sparse_categorical_accuracy: 0.9267 - val_loss: 1.1075 - val_sparse_categorical_accuracy: 0.7254 - lr: 5.0000e-04
# Epoch 53/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.5505 - val_sparse_categorical_accuracy: 0.7712 - lr: 5.0000e-04
# Epoch 54/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1810 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.2010 - val_sparse_categorical_accuracy: 0.9307 - lr: 5.0000e-04
# Epoch 55/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9288 - val_loss: 0.1856 - val_sparse_categorical_accuracy: 0.9237 - lr: 5.0000e-04
# Epoch 56/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1710 - sparse_categorical_accuracy: 0.9344 - val_loss: 0.2297 - val_sparse_categorical_accuracy: 0.8988 - lr: 5.0000e-04
# Epoch 57/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1645 - sparse_categorical_accuracy: 0.9403 - val_loss: 0.1902 - val_sparse_categorical_accuracy: 0.9223 - lr: 5.0000e-04
# Epoch 58/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1602 - sparse_categorical_accuracy: 0.9406 - val_loss: 0.1769 - val_sparse_categorical_accuracy: 0.9307 - lr: 5.0000e-04
# Epoch 59/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1627 - sparse_categorical_accuracy: 0.9406 - val_loss: 0.2412 - val_sparse_categorical_accuracy: 0.8738 - lr: 5.0000e-04
# Epoch 60/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.2129 - val_sparse_categorical_accuracy: 0.9140 - lr: 5.0000e-04
# Epoch 61/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1473 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.8635 - val_sparse_categorical_accuracy: 0.7226 - lr: 5.0000e-04
# Epoch 62/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1379 - sparse_categorical_accuracy: 0.9507 - val_loss: 0.4189 - val_sparse_categorical_accuracy: 0.8031 - lr: 5.0000e-04
# Epoch 63/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.1378 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.2686 - val_sparse_categorical_accuracy: 0.8793 - lr: 5.0000e-04
# Epoch 64/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9472 - val_loss: 0.1974 - val_sparse_categorical_accuracy: 0.9085 - lr: 5.0000e-04
# Epoch 65/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9521 - val_loss: 0.3574 - val_sparse_categorical_accuracy: 0.8280 - lr: 5.0000e-04
# Epoch 66/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1388 - sparse_categorical_accuracy: 0.9500 - val_loss: 0.1256 - val_sparse_categorical_accuracy: 0.9584 - lr: 5.0000e-04
# Epoch 67/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1259 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3011 - val_sparse_categorical_accuracy: 0.8530 - lr: 5.0000e-04
# Epoch 68/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1218 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.2357 - val_sparse_categorical_accuracy: 0.8779 - lr: 5.0000e-04
# Epoch 69/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.1338 - val_sparse_categorical_accuracy: 0.9542 - lr: 5.0000e-04
# Epoch 70/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1277 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.6632 - val_sparse_categorical_accuracy: 0.7767 - lr: 5.0000e-04
# Epoch 71/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1252 - sparse_categorical_accuracy: 0.9590 - val_loss: 1.6959 - val_sparse_categorical_accuracy: 0.5825 - lr: 5.0000e-04
# Epoch 72/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.8966 - val_sparse_categorical_accuracy: 0.7448 - lr: 5.0000e-04
# Epoch 73/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1196 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1073 - val_sparse_categorical_accuracy: 0.9570 - lr: 5.0000e-04
# Epoch 74/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1324 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.1815 - val_sparse_categorical_accuracy: 0.9196 - lr: 5.0000e-04
# Epoch 75/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1164 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1732 - val_sparse_categorical_accuracy: 0.9390 - lr: 5.0000e-04
# Epoch 76/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1124 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.1418 - val_sparse_categorical_accuracy: 0.9515 - lr: 5.0000e-04
# Epoch 77/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1172 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.3120 - val_sparse_categorical_accuracy: 0.8419 - lr: 5.0000e-04
# Epoch 78/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1227 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.1557 - val_sparse_categorical_accuracy: 0.9487 - lr: 5.0000e-04
# Epoch 79/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1127 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.1729 - val_sparse_categorical_accuracy: 0.9459 - lr: 5.0000e-04
# Epoch 80/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1142 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.3182 - val_sparse_categorical_accuracy: 0.8599 - lr: 5.0000e-04
# Epoch 81/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1169 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.1394 - val_sparse_categorical_accuracy: 0.9501 - lr: 5.0000e-04
# Epoch 82/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1068 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.2139 - val_sparse_categorical_accuracy: 0.9029 - lr: 5.0000e-04
# Epoch 83/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1142 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.1212 - val_sparse_categorical_accuracy: 0.9487 - lr: 5.0000e-04
# Epoch 84/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1093 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.1406 - val_sparse_categorical_accuracy: 0.9528 - lr: 5.0000e-04
# Epoch 85/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1052 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.1610 - val_sparse_categorical_accuracy: 0.9251 - lr: 5.0000e-04
# Epoch 86/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.1137 - val_sparse_categorical_accuracy: 0.9542 - lr: 5.0000e-04
# Epoch 87/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1096 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.2354 - val_sparse_categorical_accuracy: 0.8835 - lr: 5.0000e-04
# Epoch 88/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1144 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.1068 - val_sparse_categorical_accuracy: 0.9598 - lr: 5.0000e-04
# Epoch 89/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1146 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.1310 - val_sparse_categorical_accuracy: 0.9515 - lr: 5.0000e-04
# Epoch 90/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1111 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1007 - val_sparse_categorical_accuracy: 0.9653 - lr: 5.0000e-04
# Epoch 91/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1067 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.2213 - val_sparse_categorical_accuracy: 0.9057 - lr: 5.0000e-04
# Epoch 92/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.1250 - val_sparse_categorical_accuracy: 0.9459 - lr: 5.0000e-04
# Epoch 93/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1105 - val_sparse_categorical_accuracy: 0.9653 - lr: 5.0000e-04
# Epoch 94/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1063 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.0977 - val_sparse_categorical_accuracy: 0.9653 - lr: 5.0000e-04
# Epoch 95/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.3920 - val_sparse_categorical_accuracy: 0.8308 - lr: 5.0000e-04
# Epoch 96/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1096 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.4831 - val_sparse_categorical_accuracy: 0.7989 - lr: 5.0000e-04
# Epoch 97/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1075 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1113 - val_sparse_categorical_accuracy: 0.9570 - lr: 5.0000e-04
# Epoch 98/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1072 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1276 - val_sparse_categorical_accuracy: 0.9431 - lr: 5.0000e-04
# Epoch 99/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1038 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.2345 - val_sparse_categorical_accuracy: 0.9112 - lr: 5.0000e-04
# Epoch 100/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0984 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1280 - val_sparse_categorical_accuracy: 0.9487 - lr: 5.0000e-04
# Epoch 101/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0995 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.2715 - val_sparse_categorical_accuracy: 0.8766 - lr: 5.0000e-04
# Epoch 102/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1045 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.1896 - val_sparse_categorical_accuracy: 0.9154 - lr: 5.0000e-04
# Epoch 103/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1020 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.1129 - val_sparse_categorical_accuracy: 0.9584 - lr: 5.0000e-04
# Epoch 104/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.4442 - val_sparse_categorical_accuracy: 0.8100 - lr: 5.0000e-04
# Epoch 105/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.2308 - val_sparse_categorical_accuracy: 0.9057 - lr: 5.0000e-04
# Epoch 106/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1027 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 0.9528 - lr: 5.0000e-04
# Epoch 107/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1067 - sparse_categorical_accuracy: 0.9601 - val_loss: 1.0420 - val_sparse_categorical_accuracy: 0.6505 - lr: 5.0000e-04
# Epoch 108/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0979 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1400 - val_sparse_categorical_accuracy: 0.9501 - lr: 5.0000e-04
# Epoch 109/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1101 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.1166 - val_sparse_categorical_accuracy: 0.9501 - lr: 5.0000e-04
# Epoch 110/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.1001 - val_sparse_categorical_accuracy: 0.9639 - lr: 5.0000e-04
# Epoch 111/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0982 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.2318 - val_sparse_categorical_accuracy: 0.8932 - lr: 5.0000e-04
# Epoch 112/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1042 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1043 - val_sparse_categorical_accuracy: 0.9584 - lr: 5.0000e-04
# Epoch 113/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.1017 - val_sparse_categorical_accuracy: 0.9584 - lr: 5.0000e-04
# Epoch 114/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1122 - val_sparse_categorical_accuracy: 0.9626 - lr: 5.0000e-04
# Epoch 115/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.1059 - val_sparse_categorical_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 116/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1470 - val_sparse_categorical_accuracy: 0.9362 - lr: 2.5000e-04
# Epoch 117/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0934 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.1495 - val_sparse_categorical_accuracy: 0.9390 - lr: 2.5000e-04
# Epoch 118/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0958 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1198 - val_sparse_categorical_accuracy: 0.9501 - lr: 2.5000e-04
# Epoch 119/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0909 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1449 - val_sparse_categorical_accuracy: 0.9445 - lr: 2.5000e-04
# Epoch 120/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0856 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1311 - val_sparse_categorical_accuracy: 0.9459 - lr: 2.5000e-04
# Epoch 121/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0915 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.0848 - val_sparse_categorical_accuracy: 0.9667 - lr: 2.5000e-04
# Epoch 122/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.0861 - val_sparse_categorical_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 123/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.1982 - val_sparse_categorical_accuracy: 0.9015 - lr: 2.5000e-04
# Epoch 124/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0899 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.1646 - val_sparse_categorical_accuracy: 0.9390 - lr: 2.5000e-04
# Epoch 125/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.0839 - val_sparse_categorical_accuracy: 0.9639 - lr: 2.5000e-04
# Epoch 126/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0918 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.1050 - val_sparse_categorical_accuracy: 0.9584 - lr: 2.5000e-04
# Epoch 127/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.0868 - val_sparse_categorical_accuracy: 0.9750 - lr: 2.5000e-04
# Epoch 128/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 129/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.0812 - val_sparse_categorical_accuracy: 0.9750 - lr: 2.5000e-04
# Epoch 130/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0864 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.1110 - val_sparse_categorical_accuracy: 0.9556 - lr: 2.5000e-04
# Epoch 131/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0871 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.1019 - val_sparse_categorical_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 132/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1274 - val_sparse_categorical_accuracy: 0.9501 - lr: 2.5000e-04
# Epoch 133/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0882 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.0793 - val_sparse_categorical_accuracy: 0.9639 - lr: 2.5000e-04
# Epoch 134/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0851 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.1404 - val_sparse_categorical_accuracy: 0.9445 - lr: 2.5000e-04
# Epoch 135/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0864 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.0872 - val_sparse_categorical_accuracy: 0.9695 - lr: 2.5000e-04
# Epoch 136/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.0872 - val_sparse_categorical_accuracy: 0.9667 - lr: 2.5000e-04
# Epoch 137/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0851 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.0881 - val_sparse_categorical_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 138/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0894 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.0822 - val_sparse_categorical_accuracy: 0.9723 - lr: 2.5000e-04
# Epoch 139/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0846 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.0899 - val_sparse_categorical_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 140/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1071 - val_sparse_categorical_accuracy: 0.9556 - lr: 2.5000e-04
# Epoch 141/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0799 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.0912 - val_sparse_categorical_accuracy: 0.9681 - lr: 2.5000e-04
# Epoch 142/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1252 - val_sparse_categorical_accuracy: 0.9584 - lr: 2.5000e-04
# Epoch 143/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.1195 - val_sparse_categorical_accuracy: 0.9487 - lr: 2.5000e-04
# Epoch 144/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0808 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9667 - lr: 2.5000e-04
# Epoch 145/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0884 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.1207 - val_sparse_categorical_accuracy: 0.9473 - lr: 2.5000e-04
# Epoch 146/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0890 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.1178 - val_sparse_categorical_accuracy: 0.9542 - lr: 2.5000e-04
# Epoch 147/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0862 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1219 - val_sparse_categorical_accuracy: 0.9487 - lr: 2.5000e-04
# Epoch 148/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0935 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.1304 - val_sparse_categorical_accuracy: 0.9473 - lr: 2.5000e-04
# Epoch 149/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0816 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 150/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0934 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.0865 - val_sparse_categorical_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 151/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0805 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.4906 - val_sparse_categorical_accuracy: 0.8266 - lr: 2.5000e-04
# Epoch 152/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.3743 - val_sparse_categorical_accuracy: 0.8516 - lr: 2.5000e-04
# Epoch 153/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0905 - val_sparse_categorical_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 154/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0810 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.2500e-04
# Epoch 155/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0801 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.2500e-04
# Epoch 156/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.0871 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 157/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0839 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.0760 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 158/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0819 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.2500e-04
# Epoch 159/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0803 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0784 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.2500e-04
# Epoch 160/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0755 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1022 - val_sparse_categorical_accuracy: 0.9612 - lr: 1.2500e-04
# Epoch 161/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.0806 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.2500e-04
# Epoch 162/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.0917 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 163/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0773 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.2500e-04
# Epoch 164/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0724 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0809 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.2500e-04
# Epoch 165/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0753 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0869 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 166/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0736 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0977 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.2500e-04
# Epoch 167/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0800 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.2500e-04
# Epoch 168/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0807 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.2500e-04
# Epoch 169/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0815 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.1104 - val_sparse_categorical_accuracy: 0.9570 - lr: 1.2500e-04
# Epoch 170/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0754 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1082 - val_sparse_categorical_accuracy: 0.9528 - lr: 1.2500e-04
# Epoch 171/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1157 - val_sparse_categorical_accuracy: 0.9542 - lr: 1.2500e-04
# Epoch 172/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 173/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0777 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0796 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 174/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0828 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 175/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1305 - val_sparse_categorical_accuracy: 0.9487 - lr: 1.2500e-04
# Epoch 176/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0754 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 177/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0739 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.1028 - val_sparse_categorical_accuracy: 0.9556 - lr: 1.2500e-04
# Epoch 178/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0713 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 179/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.0904 - val_sparse_categorical_accuracy: 0.9612 - lr: 1.0000e-04
# Epoch 180/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0776 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 181/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0836 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 182/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0866 - val_sparse_categorical_accuracy: 0.9639 - lr: 1.0000e-04
# Epoch 183/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0737 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0832 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 184/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.0000e-04
# Epoch 185/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0804 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 186/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0687 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0824 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 187/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.0767 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 188/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0754 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0803 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 189/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0786 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0809 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 190/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0935 - val_sparse_categorical_accuracy: 0.9612 - lr: 1.0000e-04
# Epoch 191/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0806 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 192/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0687 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9639 - lr: 1.0000e-04
# Epoch 193/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0803 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 194/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0744 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1004 - val_sparse_categorical_accuracy: 0.9598 - lr: 1.0000e-04
# Epoch 195/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0857 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 196/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 197/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0716 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 198/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0722 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0811 - val_sparse_categorical_accuracy: 0.9639 - lr: 1.0000e-04
# Epoch 199/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0822 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 200/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0813 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 201/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0747 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9639 - lr: 1.0000e-04
# Epoch 202/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0706 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 203/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0738 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0787 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 204/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0848 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 205/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.0781 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 206/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0662 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0875 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 207/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1170 - val_sparse_categorical_accuracy: 0.9542 - lr: 1.0000e-04
# Epoch 207: early stopping

# %% [markdown]
# ## Evaluate model on test data

# %%
# !ls
# Out:
# best_model.h5  model.png  raw.githubusercontent.com  sample_data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9667
# Test accuracy 0.9666666388511658
# Test loss 0.0953950509428978

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs.
# However, by observing the validation accuracy we can see how the network still needs
# training until it reaches almost 0.97 for both the validation and the training accuracy
# after 200 epochs.
