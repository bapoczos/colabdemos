# %% [markdown]
# # Timeseries classification with a Transformer model
#
# **Author:** [Theodoros Ntakouris](https://github.com/ntakouris)<br>
# **Date created:** 2021/06/25<br>
# **Last modified:** 2022/03/27 by B. Poczos<br>
# **Description:** This notebook demonstrates how to do timeseries classification using a Transformer model. <br>
# **Source:** https://keras.io/examples/timeseries/timeseries_classification_transformer/

# %% [markdown]
# ## Introduction
#
# This is the Transformer architecture from
# [Attention Is All You Need](https://arxiv.org/abs/1706.03762),
# applied to timeseries instead of natural language.
#
# This example requires TensorFlow 2.4 or higher.
#
# ## Load the dataset
#
# We are going to use the same dataset and preprocessing as the
# [TimeSeries Classification from Scratch](https://keras.io/examples/timeseries/timeseries_classification_from_scratch)
# example.

# %%
# !nvidia-smi
# Out:
# Sun Mar 27 17:36:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np


def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3601, 500, 1)
# (3601,)
# (1320, 500, 1)
# (1320,)

# %%
n_classes = len(np.unique(y_train))
print(f'n_classes: {n_classes}')

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0
# Out:
# n_classes: 2

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3601, 500, 1)
# (3601,)
# (1320, 500, 1)
# (1320,)

# %% [markdown]
# ## Build the model
#
# Our model processes a tensor of shape `(batch size, sequence length, features)`,
# where `sequence length` is the number of time steps and `features` is the dimension of each input
# timeseries.

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# We include **residual connections, layer normalization, and dropout**.
# The resulting layer can be stacked multiple times.
#
# The projection layers are implemented through `keras.layers.Conv1D`.

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %% [markdown]
# The main part of our model is now complete. We can **stack multiple of those
# `transformer_encoder` blocks** and we can also proceed to add the final
# Multi-Layer Perceptron classification head. Apart from a stack of `Dense`
# layers, we need to reduce the output tensor of the `TransformerEncoder` part of
# our model down to a vector of features for each data point in the current
# batch. A common way to achieve this is to use a pooling layer. For
# this example, a `GlobalAveragePooling1D` layer is sufficient.

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
input_shape = x_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 1)]     0           []
#
#  layer_normalization (LayerNorm  (None, 500, 1)      2           ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 500, 1)      7169        ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 500, 1)       0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 500, 1)      0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 500, 4)       8           ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 500, 4)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 500, 1)       5           ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 500, 1)      0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 500, 1)      7169        ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 500, 1)       0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 500, 1)      0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 500, 4)       8           ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 500, 4)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 500, 1)       5           ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 500, 1)      0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 500, 1)      7169        ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 500, 1)       0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 500, 1)      0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 500, 4)       8           ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 500, 4)       0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 500, 1)       5           ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 500, 1)      0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 500, 1)      7169        ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 500, 1)       0           ['multi_head_attention_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 500, 1)      0           ['dropout_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 500, 1)      2           ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 500, 4)       8           ['layer_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 500, 4)       0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 500, 1)       5           ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 500, 1)      0           ['conv1d_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 500)         0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          64128       ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            258         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 93,130
# Trainable params: 93,130
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model)

# %% [markdown]
# ## Train

# %% [markdown]
# **The below cell will need about 50 minutes to complete** (15 sec per epocs, 200 epoczs)

# %%
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
)
# Out:
# Epoch 1/200
# 45/45 [==============================] - 25s 309ms/step - loss: 1.2651 - sparse_categorical_accuracy: 0.5066 - val_loss: 0.7707 - val_sparse_categorical_accuracy: 0.5368
# Epoch 2/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.9270 - sparse_categorical_accuracy: 0.5326 - val_loss: 0.6936 - val_sparse_categorical_accuracy: 0.5881
# Epoch 3/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.8309 - sparse_categorical_accuracy: 0.5667 - val_loss: 0.6429 - val_sparse_categorical_accuracy: 0.6186
# Epoch 4/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.7723 - sparse_categorical_accuracy: 0.5892 - val_loss: 0.6160 - val_sparse_categorical_accuracy: 0.6477
# Epoch 5/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.7330 - sparse_categorical_accuracy: 0.6191 - val_loss: 0.5945 - val_sparse_categorical_accuracy: 0.6630
# Epoch 6/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.7019 - sparse_categorical_accuracy: 0.6417 - val_loss: 0.5739 - val_sparse_categorical_accuracy: 0.6935
# Epoch 7/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.6777 - sparse_categorical_accuracy: 0.6559 - val_loss: 0.5600 - val_sparse_categorical_accuracy: 0.7004
# Epoch 8/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.6240 - sparse_categorical_accuracy: 0.6837 - val_loss: 0.5459 - val_sparse_categorical_accuracy: 0.7184
# Epoch 9/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.6157 - sparse_categorical_accuracy: 0.6858 - val_loss: 0.5400 - val_sparse_categorical_accuracy: 0.7171
# Epoch 10/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.6013 - sparse_categorical_accuracy: 0.6872 - val_loss: 0.5298 - val_sparse_categorical_accuracy: 0.7351
# Epoch 11/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.5752 - sparse_categorical_accuracy: 0.7167 - val_loss: 0.5244 - val_sparse_categorical_accuracy: 0.7379
# Epoch 12/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.5571 - sparse_categorical_accuracy: 0.7194 - val_loss: 0.5203 - val_sparse_categorical_accuracy: 0.7365
# Epoch 13/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.5305 - sparse_categorical_accuracy: 0.7378 - val_loss: 0.5143 - val_sparse_categorical_accuracy: 0.7406
# Epoch 14/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.5248 - sparse_categorical_accuracy: 0.7365 - val_loss: 0.5057 - val_sparse_categorical_accuracy: 0.7476
# Epoch 15/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.5198 - sparse_categorical_accuracy: 0.7451 - val_loss: 0.5002 - val_sparse_categorical_accuracy: 0.7517
# Epoch 16/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.5065 - sparse_categorical_accuracy: 0.7451 - val_loss: 0.4962 - val_sparse_categorical_accuracy: 0.7573
# Epoch 17/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4848 - sparse_categorical_accuracy: 0.7670 - val_loss: 0.4888 - val_sparse_categorical_accuracy: 0.7559
# Epoch 18/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4804 - sparse_categorical_accuracy: 0.7688 - val_loss: 0.4846 - val_sparse_categorical_accuracy: 0.7628
# Epoch 19/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4734 - sparse_categorical_accuracy: 0.7736 - val_loss: 0.4832 - val_sparse_categorical_accuracy: 0.7670
# Epoch 20/200
# 45/45 [==============================] - 13s 300ms/step - loss: 0.4499 - sparse_categorical_accuracy: 0.7896 - val_loss: 0.4778 - val_sparse_categorical_accuracy: 0.7670
# Epoch 21/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4650 - sparse_categorical_accuracy: 0.7878 - val_loss: 0.4715 - val_sparse_categorical_accuracy: 0.7781
# Epoch 22/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4422 - sparse_categorical_accuracy: 0.7979 - val_loss: 0.4670 - val_sparse_categorical_accuracy: 0.7850
# Epoch 23/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4337 - sparse_categorical_accuracy: 0.8042 - val_loss: 0.4635 - val_sparse_categorical_accuracy: 0.7809
# Epoch 24/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4247 - sparse_categorical_accuracy: 0.8073 - val_loss: 0.4604 - val_sparse_categorical_accuracy: 0.7836
# Epoch 25/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4211 - sparse_categorical_accuracy: 0.8128 - val_loss: 0.4550 - val_sparse_categorical_accuracy: 0.7850
# Epoch 26/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4282 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.4515 - val_sparse_categorical_accuracy: 0.7906
# Epoch 27/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.4028 - sparse_categorical_accuracy: 0.8156 - val_loss: 0.4452 - val_sparse_categorical_accuracy: 0.8003
# Epoch 28/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3940 - sparse_categorical_accuracy: 0.8319 - val_loss: 0.4415 - val_sparse_categorical_accuracy: 0.8044
# Epoch 29/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3975 - sparse_categorical_accuracy: 0.8323 - val_loss: 0.4393 - val_sparse_categorical_accuracy: 0.8072
# Epoch 30/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.4361 - val_sparse_categorical_accuracy: 0.8141
# Epoch 31/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3792 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.4327 - val_sparse_categorical_accuracy: 0.8086
# Epoch 32/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3787 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.4304 - val_sparse_categorical_accuracy: 0.8044
# Epoch 33/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3735 - sparse_categorical_accuracy: 0.8385 - val_loss: 0.4262 - val_sparse_categorical_accuracy: 0.8100
# Epoch 34/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3707 - sparse_categorical_accuracy: 0.8472 - val_loss: 0.4254 - val_sparse_categorical_accuracy: 0.8128
# Epoch 35/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.3585 - sparse_categorical_accuracy: 0.8590 - val_loss: 0.4207 - val_sparse_categorical_accuracy: 0.8211
# Epoch 36/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3509 - sparse_categorical_accuracy: 0.8608 - val_loss: 0.4195 - val_sparse_categorical_accuracy: 0.8239
# Epoch 37/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3566 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.4146 - val_sparse_categorical_accuracy: 0.8225
# Epoch 38/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3495 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.4141 - val_sparse_categorical_accuracy: 0.8239
# Epoch 39/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3337 - sparse_categorical_accuracy: 0.8684 - val_loss: 0.4124 - val_sparse_categorical_accuracy: 0.8141
# Epoch 40/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3453 - sparse_categorical_accuracy: 0.8632 - val_loss: 0.4093 - val_sparse_categorical_accuracy: 0.8266
# Epoch 41/200
# 45/45 [==============================] - 14s 304ms/step - loss: 0.3316 - sparse_categorical_accuracy: 0.8684 - val_loss: 0.4052 - val_sparse_categorical_accuracy: 0.8280
# Epoch 42/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3327 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.4028 - val_sparse_categorical_accuracy: 0.8308
# Epoch 43/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3318 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.4011 - val_sparse_categorical_accuracy: 0.8363
# Epoch 44/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3227 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.3996 - val_sparse_categorical_accuracy: 0.8308
# Epoch 45/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3211 - sparse_categorical_accuracy: 0.8757 - val_loss: 0.3950 - val_sparse_categorical_accuracy: 0.8363
# Epoch 46/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3055 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.3926 - val_sparse_categorical_accuracy: 0.8363
# Epoch 47/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3104 - sparse_categorical_accuracy: 0.8771 - val_loss: 0.3904 - val_sparse_categorical_accuracy: 0.8377
# Epoch 48/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.2944 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.3905 - val_sparse_categorical_accuracy: 0.8266
# Epoch 49/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3001 - sparse_categorical_accuracy: 0.8875 - val_loss: 0.3863 - val_sparse_categorical_accuracy: 0.8447
# Epoch 50/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.3021 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.3869 - val_sparse_categorical_accuracy: 0.8391
# Epoch 51/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.8840 - val_loss: 0.3874 - val_sparse_categorical_accuracy: 0.8377
# Epoch 52/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2933 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.3801 - val_sparse_categorical_accuracy: 0.8433
# Epoch 53/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2797 - sparse_categorical_accuracy: 0.8976 - val_loss: 0.3800 - val_sparse_categorical_accuracy: 0.8377
# Epoch 54/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.3786 - val_sparse_categorical_accuracy: 0.8363
# Epoch 55/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2823 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.3753 - val_sparse_categorical_accuracy: 0.8391
# Epoch 56/200
# 45/45 [==============================] - 14s 304ms/step - loss: 0.2756 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.3727 - val_sparse_categorical_accuracy: 0.8474
# Epoch 57/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2752 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.3745 - val_sparse_categorical_accuracy: 0.8460
# Epoch 58/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2715 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.3714 - val_sparse_categorical_accuracy: 0.8558
# Epoch 59/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2703 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.3705 - val_sparse_categorical_accuracy: 0.8488
# Epoch 60/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2640 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.3677 - val_sparse_categorical_accuracy: 0.8516
# Epoch 61/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2686 - sparse_categorical_accuracy: 0.9069 - val_loss: 0.3660 - val_sparse_categorical_accuracy: 0.8516
# Epoch 62/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2636 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.3633 - val_sparse_categorical_accuracy: 0.8544
# Epoch 63/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2558 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.3623 - val_sparse_categorical_accuracy: 0.8599
# Epoch 64/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2539 - sparse_categorical_accuracy: 0.9090 - val_loss: 0.3615 - val_sparse_categorical_accuracy: 0.8585
# Epoch 65/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2518 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.3618 - val_sparse_categorical_accuracy: 0.8544
# Epoch 66/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2438 - sparse_categorical_accuracy: 0.9156 - val_loss: 0.3601 - val_sparse_categorical_accuracy: 0.8627
# Epoch 67/200
# 45/45 [==============================] - 13s 300ms/step - loss: 0.2480 - sparse_categorical_accuracy: 0.9076 - val_loss: 0.3571 - val_sparse_categorical_accuracy: 0.8585
# Epoch 68/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.2471 - sparse_categorical_accuracy: 0.9066 - val_loss: 0.3561 - val_sparse_categorical_accuracy: 0.8516
# Epoch 69/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2393 - sparse_categorical_accuracy: 0.9132 - val_loss: 0.3535 - val_sparse_categorical_accuracy: 0.8530
# Epoch 70/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.3521 - val_sparse_categorical_accuracy: 0.8530
# Epoch 71/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2378 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.3508 - val_sparse_categorical_accuracy: 0.8599
# Epoch 72/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2300 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.3501 - val_sparse_categorical_accuracy: 0.8613
# Epoch 73/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2301 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.8641
# Epoch 74/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2356 - sparse_categorical_accuracy: 0.9167 - val_loss: 0.3473 - val_sparse_categorical_accuracy: 0.8641
# Epoch 75/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2369 - sparse_categorical_accuracy: 0.9156 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.8530
# Epoch 76/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2333 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.3435 - val_sparse_categorical_accuracy: 0.8558
# Epoch 77/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2225 - sparse_categorical_accuracy: 0.9226 - val_loss: 0.3409 - val_sparse_categorical_accuracy: 0.8682
# Epoch 78/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2305 - sparse_categorical_accuracy: 0.9142 - val_loss: 0.3387 - val_sparse_categorical_accuracy: 0.8669
# Epoch 79/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.2179 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.3401 - val_sparse_categorical_accuracy: 0.8710
# Epoch 80/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2158 - sparse_categorical_accuracy: 0.9264 - val_loss: 0.3367 - val_sparse_categorical_accuracy: 0.8641
# Epoch 81/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2141 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.3371 - val_sparse_categorical_accuracy: 0.8669
# Epoch 82/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.2141 - sparse_categorical_accuracy: 0.9240 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8655
# Epoch 83/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.2146 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.8627
# Epoch 84/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.2082 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.8696
# Epoch 85/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2034 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.3346 - val_sparse_categorical_accuracy: 0.8682
# Epoch 86/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2047 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.3341 - val_sparse_categorical_accuracy: 0.8627
# Epoch 87/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1978 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8696
# Epoch 88/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1976 - sparse_categorical_accuracy: 0.9323 - val_loss: 0.3315 - val_sparse_categorical_accuracy: 0.8682
# Epoch 89/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2029 - sparse_categorical_accuracy: 0.9306 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8696
# Epoch 90/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.2013 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.3327 - val_sparse_categorical_accuracy: 0.8738
# Epoch 91/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1956 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.3307 - val_sparse_categorical_accuracy: 0.8710
# Epoch 92/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1999 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.3291 - val_sparse_categorical_accuracy: 0.8655
# Epoch 93/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1932 - sparse_categorical_accuracy: 0.9312 - val_loss: 0.3333 - val_sparse_categorical_accuracy: 0.8696
# Epoch 94/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1959 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.3322 - val_sparse_categorical_accuracy: 0.8682
# Epoch 95/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1913 - sparse_categorical_accuracy: 0.9326 - val_loss: 0.3311 - val_sparse_categorical_accuracy: 0.8669
# Epoch 96/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1874 - sparse_categorical_accuracy: 0.9351 - val_loss: 0.3277 - val_sparse_categorical_accuracy: 0.8752
# Epoch 97/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1818 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.3292 - val_sparse_categorical_accuracy: 0.8724
# Epoch 98/200
# 45/45 [==============================] - 13s 300ms/step - loss: 0.1840 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.3269 - val_sparse_categorical_accuracy: 0.8738
# Epoch 99/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1775 - sparse_categorical_accuracy: 0.9410 - val_loss: 0.3292 - val_sparse_categorical_accuracy: 0.8682
# Epoch 100/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1822 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.3265 - val_sparse_categorical_accuracy: 0.8766
# Epoch 101/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1808 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.3244 - val_sparse_categorical_accuracy: 0.8724
# Epoch 102/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1682 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.8682
# Epoch 103/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1841 - sparse_categorical_accuracy: 0.9375 - val_loss: 0.3281 - val_sparse_categorical_accuracy: 0.8696
# Epoch 104/200
# 45/45 [==============================] - 14s 302ms/step - loss: 0.1757 - sparse_categorical_accuracy: 0.9410 - val_loss: 0.3252 - val_sparse_categorical_accuracy: 0.8738
# Epoch 105/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.1736 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.3257 - val_sparse_categorical_accuracy: 0.8724
# Epoch 106/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.1717 - sparse_categorical_accuracy: 0.9410 - val_loss: 0.3216 - val_sparse_categorical_accuracy: 0.8821
# Epoch 107/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1700 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.3230 - val_sparse_categorical_accuracy: 0.8766
# Epoch 108/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1734 - sparse_categorical_accuracy: 0.9337 - val_loss: 0.3227 - val_sparse_categorical_accuracy: 0.8752
# Epoch 109/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.1655 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.3222 - val_sparse_categorical_accuracy: 0.8766
# Epoch 110/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1623 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.3221 - val_sparse_categorical_accuracy: 0.8821
# Epoch 111/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1578 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.3216 - val_sparse_categorical_accuracy: 0.8710
# Epoch 112/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1586 - sparse_categorical_accuracy: 0.9448 - val_loss: 0.3206 - val_sparse_categorical_accuracy: 0.8724
# Epoch 113/200
# 45/45 [==============================] - 13s 300ms/step - loss: 0.1638 - sparse_categorical_accuracy: 0.9420 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8766
# Epoch 114/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1578 - sparse_categorical_accuracy: 0.9455 - val_loss: 0.3208 - val_sparse_categorical_accuracy: 0.8738
# Epoch 115/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1506 - sparse_categorical_accuracy: 0.9538 - val_loss: 0.3231 - val_sparse_categorical_accuracy: 0.8655
# Epoch 116/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1529 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.3206 - val_sparse_categorical_accuracy: 0.8766
# Epoch 117/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1573 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.3199 - val_sparse_categorical_accuracy: 0.8710
# Epoch 118/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9497 - val_loss: 0.3210 - val_sparse_categorical_accuracy: 0.8779
# Epoch 119/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1541 - sparse_categorical_accuracy: 0.9507 - val_loss: 0.3271 - val_sparse_categorical_accuracy: 0.8669
# Epoch 120/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1578 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8738
# Epoch 121/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1553 - sparse_categorical_accuracy: 0.9472 - val_loss: 0.3184 - val_sparse_categorical_accuracy: 0.8821
# Epoch 122/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1561 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.3252 - val_sparse_categorical_accuracy: 0.8724
# Epoch 123/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1506 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.8766
# Epoch 124/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1481 - sparse_categorical_accuracy: 0.9517 - val_loss: 0.3177 - val_sparse_categorical_accuracy: 0.8752
# Epoch 125/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1466 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.3193 - val_sparse_categorical_accuracy: 0.8710
# Epoch 126/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1435 - sparse_categorical_accuracy: 0.9490 - val_loss: 0.3215 - val_sparse_categorical_accuracy: 0.8752
# Epoch 127/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1464 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.3213 - val_sparse_categorical_accuracy: 0.8696
# Epoch 128/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1455 - sparse_categorical_accuracy: 0.9531 - val_loss: 0.3184 - val_sparse_categorical_accuracy: 0.8807
# Epoch 129/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1484 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.8779
# Epoch 130/200
# 45/45 [==============================] - 14s 302ms/step - loss: 0.1575 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.3203 - val_sparse_categorical_accuracy: 0.8793
# Epoch 131/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1474 - sparse_categorical_accuracy: 0.9503 - val_loss: 0.3209 - val_sparse_categorical_accuracy: 0.8710
# Epoch 132/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1387 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.3220 - val_sparse_categorical_accuracy: 0.8738
# Epoch 133/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1450 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.3167 - val_sparse_categorical_accuracy: 0.8807
# Epoch 134/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1343 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.8835
# Epoch 135/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1406 - sparse_categorical_accuracy: 0.9538 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8779
# Epoch 136/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1320 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3184 - val_sparse_categorical_accuracy: 0.8807
# Epoch 137/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1290 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8738
# Epoch 138/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1298 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.3203 - val_sparse_categorical_accuracy: 0.8793
# Epoch 139/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1322 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.3232 - val_sparse_categorical_accuracy: 0.8835
# Epoch 140/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1298 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.3220 - val_sparse_categorical_accuracy: 0.8779
# Epoch 141/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1329 - sparse_categorical_accuracy: 0.9538 - val_loss: 0.3183 - val_sparse_categorical_accuracy: 0.8779
# Epoch 142/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3179 - val_sparse_categorical_accuracy: 0.8877
# Epoch 143/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1295 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.3165 - val_sparse_categorical_accuracy: 0.8835
# Epoch 144/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1355 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.3155 - val_sparse_categorical_accuracy: 0.8849
# Epoch 145/200
# 45/45 [==============================] - 13s 300ms/step - loss: 0.1290 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8779
# Epoch 146/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1230 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3170 - val_sparse_categorical_accuracy: 0.8779
# Epoch 147/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1227 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8710
# Epoch 148/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.3240 - val_sparse_categorical_accuracy: 0.8710
# Epoch 149/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1182 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.3231 - val_sparse_categorical_accuracy: 0.8724
# Epoch 150/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1217 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.3176 - val_sparse_categorical_accuracy: 0.8738
# Epoch 151/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.3193 - val_sparse_categorical_accuracy: 0.8724
# Epoch 152/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1205 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.3196 - val_sparse_categorical_accuracy: 0.8696
# Epoch 153/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1162 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3191 - val_sparse_categorical_accuracy: 0.8724
# Epoch 154/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1260 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.3150 - val_sparse_categorical_accuracy: 0.8710
# Epoch 155/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1212 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.3154 - val_sparse_categorical_accuracy: 0.8821
# Epoch 156/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1142 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.3118 - val_sparse_categorical_accuracy: 0.8821
# Epoch 157/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1232 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.3166 - val_sparse_categorical_accuracy: 0.8807
# Epoch 158/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1185 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.3150 - val_sparse_categorical_accuracy: 0.8821
# Epoch 159/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1101 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8793
# Epoch 160/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1150 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.3192 - val_sparse_categorical_accuracy: 0.8779
# Epoch 161/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.3188 - val_sparse_categorical_accuracy: 0.8793
# Epoch 162/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3189 - val_sparse_categorical_accuracy: 0.8779
# Epoch 163/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8779
# Epoch 164/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1163 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.3173 - val_sparse_categorical_accuracy: 0.8793
# Epoch 165/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1155 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.3187 - val_sparse_categorical_accuracy: 0.8738
# Epoch 166/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1057 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.3115 - val_sparse_categorical_accuracy: 0.8779
# Epoch 167/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1120 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3135 - val_sparse_categorical_accuracy: 0.8766
# Epoch 168/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1087 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.3138 - val_sparse_categorical_accuracy: 0.8849
# Epoch 169/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1001 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.3134 - val_sparse_categorical_accuracy: 0.8821
# Epoch 170/200
# 45/45 [==============================] - 13s 298ms/step - loss: 0.1012 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.3222 - val_sparse_categorical_accuracy: 0.8821
# Epoch 171/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3149 - val_sparse_categorical_accuracy: 0.8821
# Epoch 172/200
# 45/45 [==============================] - 14s 303ms/step - loss: 0.1054 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.3163 - val_sparse_categorical_accuracy: 0.8807
# Epoch 173/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1088 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.3192 - val_sparse_categorical_accuracy: 0.8779
# Epoch 174/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1070 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.3151 - val_sparse_categorical_accuracy: 0.8807
# Epoch 175/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.3144 - val_sparse_categorical_accuracy: 0.8793
# Epoch 176/200
# 45/45 [==============================] - 13s 299ms/step - loss: 0.0964 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3123 - val_sparse_categorical_accuracy: 0.8793

# %% [markdown]
# # Evaluate

# %%
model.evaluate(x_test, y_test, verbose=1)
# Out:
# 42/42 [==============================] - 2s 52ms/step - loss: 0.3583 - sparse_categorical_accuracy: 0.8538
# [0.3583032190799713, 0.853787899017334]

# %% [markdown]
# ## Conclusions
#
# In about 110-120 epochs (25s each on Colab), the model reaches a training
# accuracy of ~0.95, validation accuracy of ~84 and a testing
# accuracy of ~85, without hyperparameter tuning. And that is for a model
# with less than 100k parameters. Of course, parameter count and accuracy could be
# improved by a hyperparameter search and a more sophisticated learning rate
# schedule, or a different optimizer.
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/timeseries_transformer_classification) and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/timeseries_transformer_classification).
