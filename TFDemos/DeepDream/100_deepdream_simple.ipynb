# %% [markdown]
# # DeepDreaming with TensorFlow

# %% [markdown]
# Based on https://www.tensorflow.org/tutorials/generative/deepdream

# %%
# !nvidia-smi
# Out:
# Sun Oct 30 01:48:19 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
print(tf.__version__)

import numpy as np
import matplotlib as mpl

import IPython.display as display
import PIL.Image
# Out:
# 2.9.2

# %% [markdown]
# ### Load and display image

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/example_images/YellowLabradorLooking_new.jpg'

# %%
# Download an image and read it into a NumPy array.
def download(url, max_dim=None):
  name = url.split('/')[-1]
  image_path = tf.keras.utils.get_file(name, origin=url)
  img = PIL.Image.open(image_path)
  if max_dim:
    img.thumbnail((max_dim, max_dim))
  return np.array(img)

# Normalize an image (from [-1,1] to [0,255])
def deprocess(img):
  img = 255*(img + 1.0)/2.0
  return tf.cast(img, tf.uint8)

# Display an image
def show(img):
  display.display(PIL.Image.fromarray(np.array(img)))


# Downsizing the image makes it easier to work with.
original_img = download(url, max_dim=500)
show(original_img)
display.display(display.HTML('Image cc-by: <a "href=https://commons.wikimedia.org/wiki/File:Felis_catus-cat_on_snow.jpg">Von.grzanka</a>'))
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/YellowLabradorLooking_new.jpg
# 83281/83281 [==============================] - 0s 0us/step
# <PIL.Image.Image image mode=RGB size=500x412 at 0x7F87F7FA1850>
# Image cc-by: <a "href=https://commons.wikimedia.org/wiki/File:Felis_catus-cat_on_snow.jpg">Von.grzanka</a>

# %%
base_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
print([(it.name, it.output_shape) for it in base_model.layers][0:5])
print([(it.name, it.output_shape) for it in base_model.layers][-5:])
# Out:
# [('input_1', [(None, None, None, 3)]), ('conv2d', (None, None, None, 32)), ('batch_normalization', (None, None, None, 32)), ('activation', (None, None, None, 32)), ('conv2d_1', (None, None, None, 32))]
# [('activation_85', (None, None, None, 320)), ('mixed9_1', (None, None, None, 768)), ('concatenate_1', (None, None, None, 768)), ('activation_93', (None, None, None, 192)), ('mixed10', (None, None, None, 2048))]

# %%
# Maximize the activations of these layers
names = ['mixed3', 'mixed5']
layers = [base_model.get_layer(name).output for name in names]

print(layers)
# Out:
# [<KerasTensor: shape=(None, None, None, 768) dtype=float32 (created by layer 'mixed3')>, <KerasTensor: shape=(None, None, None, 768) dtype=float32 (created by layer 'mixed5')>]

# %%
# Create the feature extraction model
dream_model = tf.keras.Model(inputs=base_model.input, outputs=layers)

# %%
print(len(base_model.layers))
print(len(dream_model.layers))
# Out:
# 311
# 165

# %%
def calc_loss(img, model):
  # Pass forward the image through the model to retrieve the activations.
  # Converts the image into a batch of size 1.
  img_batch = tf.expand_dims(img, axis=0)
  layer_activations = model(img_batch)
  if len(layer_activations) == 1:
    layer_activations = [layer_activations]

  losses = []
  for act in layer_activations:
    loss = tf.math.reduce_mean(act)
    #print(loss)
    losses.append(loss)

  return  tf.reduce_sum(losses)

# %%
print(calc_loss(original_img, base_model))
print('---')
print(calc_loss(original_img, dream_model))
# Out:
# tf.Tensor(6.9696403, shape=(), dtype=float32)
# ---
# tf.Tensor(83.29388, shape=(), dtype=float32)

# %% [markdown]
# <a id='naive'></a>
# ## Simple Deep Dream

# %%
class DeepDream(tf.Module):
  def __init__(self, model):
    self.model = model
    self.steps=10
    self.step_size=tf.convert_to_tensor(0.01)

  @tf.function(
      input_signature=(
        tf.TensorSpec(shape=[None,None,3], dtype=tf.float32),
        )
  )
  def __call__(self, img):

      step_size = self.step_size
      steps = self.steps

      print("Tracing")
      loss = tf.constant(0.0)
      for n in tf.range(steps):
        with tf.GradientTape() as tape:
          # This needs gradients relative to `img`
          # `GradientTape` only watches `tf.Variable`s by default
          tape.watch(img)
          loss = calc_loss(img, self.model)

        # Calculate the gradient of the loss with respect to the pixels of the input image.
        gradients = tape.gradient(loss, img)

        # Normalize the gradients.
        gradients /= tf.math.reduce_std(gradients) + 1e-8 

        # In gradient ascent, the "loss" is maximized so that the input image increasingly "excites" the layers.
        # You can update the image by directly adding the gradients (because they're the same shape!)
        img = img + gradients*step_size
        img = tf.clip_by_value(img, -1, 1) # keep the image between -1,1

      return loss, img

# %%
deepdream = DeepDream(dream_model)

# %%
noise_img = (75+10*np.random.uniform(size=(200,200,3))).astype(np.int32)

img = noise_img

img = tf.keras.applications.inception_v3.preprocess_input(img)

img = tf.convert_to_tensor(img)

for iter in np.arange(5):
  loss, img = deepdream(img)

  #display.clear_output(wait=True)
  show(deprocess(img))
  print ("Iter {}, loss {}".format(iter, loss))
# Out:
# Tracing
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F87E0238950>
# Iter 0, loss 1.1716409921646118
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F87E03CC250>
# Iter 1, loss 1.4754037857055664
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F8792364CD0>
# Iter 2, loss 1.7004563808441162
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F87E03BE790>
# Iter 3, loss 1.8499130010604858
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F877AF4BFD0>
# Iter 4, loss 1.998826026916504

# %%
img = original_img # pixels between 0 and 255
print(np.min(img),np.max(img))

img = tf.keras.applications.inception_v3.preprocess_input(img)
img = tf.convert_to_tensor(img)

for iter in np.arange(5):
  loss, img = deepdream(img)

  #display.clear_output(wait=True)
  show(deprocess(img))
  print ("Iter {}, loss {}".format(iter, loss))
